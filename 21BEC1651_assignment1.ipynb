# %% [markdown]
# <a href="https://colab.research.google.com/github/smartinternz02/SI-GuidedProject-581874-1694635000/blob/main/21BEC1651_assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.DataFrame([[1,2,3,4],[6,7,8,9],[11,12,13,14],[16,17,18,19]])
df
# Out:
#     0   1   2   3
# 0   1   2   3   4
# 1   6   7   8   9
# 2  11  12  13  14
# 3  16  17  18  19

# %%
df.columns=['Random value 1','Random value 2','Random value 3','Random value 4']

# %%
df
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0               1               2               3               4
# 1               6               7               8               9
# 2              11              12              13              14
# 3              16              17              18              19

# %%
df.describe()
# Out:
#        Random value 1  Random value 2  Random value 3  Random value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         8.500000        9.500000       10.500000       11.500000
# std          6.454972        6.454972        6.454972        6.454972
# min          1.000000        2.000000        3.000000        4.000000
# 25%          4.750000        5.750000        6.750000        7.750000
# 50%          8.500000        9.500000       10.500000       11.500000
# 75%         12.250000       13.250000       14.250000       15.250000
# max         16.000000       17.000000       18.000000       19.000000

# %%
df.isnull().any()
# Out:
# Random value 1    False
# Random value 2    False
# Random value 3    False
# Random value 4    False
# dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Random value 1  4 non-null      int64
#  1   Random value 2  4 non-null      int64
#  2   Random value 3  4 non-null      int64
#  3   Random value 4  4 non-null      int64
# dtypes: int64(4)
# memory usage: 256.0 bytes

# %%
df.loc[:,['Random value 2','Random value 3']]
# Out:
#    Random value 2  Random value 3
# 0               2               3
# 1               7               8
# 2              12              13
# 3              17              18

# %%
df.iloc[:,[1,2]]
# Out:
#    Random value 2  Random value 3
# 0               2               3
# 1               7               8
# 2              12              13
# 3              17              18
